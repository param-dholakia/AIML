# %%
import pandas as pd

# %%
df=pd.read_csv("sum-dataset.csv")
df
# Out:
#          x       y       z
# 0     1.23    3.45    4.68
# 1     2.56    4.78    7.34
# 2     5.00    3.00    8.00
# 3     7.34    2.67   10.01
# 4     1.11    0.89    2.00
# ..     ...     ...     ...
# 95  279.99  478.11  758.10
# 96  282.86  482.64  765.49
# 97  285.72  487.16  772.88
# 98  288.59  491.68  780.27
# 99  291.46  496.20  787.66
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(df['x'],df['z'])
plt.show()

# %%
plt.scatter(df['y'],df['z'])
plt.show()

# %%
X=df[['x','y']]
X
# Out:
#          x       y
# 0     1.23    3.45
# 1     2.56    4.78
# 2     5.00    3.00
# 3     7.34    2.67
# 4     1.11    0.89
# ..     ...     ...
# 95  279.99  478.11
# 96  282.86  482.64
# 97  285.72  487.16
# 98  288.59  491.68
# 99  291.46  496.20
#
# [100 rows x 2 columns]

# %%
y=df['z']
y
# Out:
# 0       4.68
# 1       7.34
# 2       8.00
# 3      10.01
# 4       2.00
#        ...
# 95    758.10
# 96    765.49
# 97    772.88
# 98    780.27
# 99    787.66
# Name: z, Length: 100, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lr = LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
y1_pred = lr.predict([[2.5,2.5]])[0]
y1_pred
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 5.000085039021921

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([ 669.45025154,  447.8000301 ,  573.40015556,  388.69997106,
#         381.30996366,  344.36992676,    4.32962867,  647.29022939,
#          59.99964525,    4.67962894,  198.99989177,  277.86986032,
#         595.56017771,  300.02988247,  721.1603032 ,    1.99962909,
#         617.73019985,  625.12020725,  101.21973096,  285.25986771,
#         462.58004486,  706.39028844,  248.31983081,  366.52994891,
#         566.0101482 , 1463.54088013,  351.75993415,  765.50034749,
#          15.99965139,  588.18017035])

# %%
data=pd.DataFrame({'Actual':y_test,'Predicted': y_pred})
data
# Out:
#      Actual    Predicted
# 83   669.45   669.450252
# 53   447.80   447.800030
# 70   573.40   573.400156
# 45   388.70   388.699971
# 44   381.31   381.309964
# 39   344.37   344.369927
# 22     4.33     4.329629
# 80   647.28   647.290229
# 10    60.00    59.999645
# 0      4.68     4.679629
# 18   199.00   198.999892
# 30   277.87   277.869860
# 73   595.57   595.560178
# 33   300.04   300.029882
# 90   721.16   721.160303
# 4      2.00     1.999629
# 76   617.73   617.730200
# 77   625.12   625.120207
# 12   101.22   101.219731
# 31   285.26   285.259868
# 55   462.58   462.580045
# 88   706.39   706.390288
# 26   248.32   248.319831
# 42   366.53   366.529949
# 69   566.01   566.010148
# 15  1463.54  1463.540880
# 40   351.76   351.759934
# 96   765.49   765.500347
# 9     16.00    15.999651
# 72   588.18   588.180170

# %%
plt.scatter(X_test['x'],y_pred)
plt.show()

# %%
lr.score(X_test,y_pred)
# Out:
# 1.0

# %%
lr.score(X_train,y_train)
# Out:
# 0.9999999997792013

# %%
lr.score(X_test,y_test)
# Out:
# 0.9999999998495857

# %%
import joblib
joblib.dump(lr,'model_sum')
# Out:
# ['model_sum']
